# %%
pip install mplfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 4.1 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd
import yfinance as yfin
import matplotlib.pyplot as plt

#velas japonesas
import mplfinance as mpf

# %%
#Dascargar datos de Tesla
df = yfin. download("TSLA", start="2020-01-01", end="2021-01-01")
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02   28.299999   28.713333   28.114000   28.684000   28.684000
# 2020-01-03   29.366667   30.266666   29.128000   29.534000   29.534000
# 2020-01-06   29.364668   30.104000   29.333332   30.102667   30.102667
# 2020-01-07   30.760000   31.441999   30.224001   31.270666   31.270666
# 2020-01-08   31.580000   33.232666   31.215334   32.809334   32.809334
# ...                ...         ...         ...         ...         ...
# 2020-12-24  214.330002  222.029999  213.666672  220.589996  220.589996
# 2020-12-28  224.836670  227.133331  220.266663  221.229996  221.229996
# 2020-12-29  220.333328  223.300003  218.333328  221.996674  221.996674
# 2020-12-30  224.000000  232.199997  222.786667  231.593338  231.593338
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
#
#                Volume
# Date
# ...

# %%
#Comparar TESLA con un portafolio de mercado (S&P500)
#Dascargar datos de S&P500
df2 = yfin. download("^GSPC", start="2020-01-01", end="2021-01-01")
df2
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-01-02  3244.669922  3258.139893  3235.530029  3257.850098  3257.850098
# 2020-01-03  3226.360107  3246.149902  3222.340088  3234.850098  3234.850098
# 2020-01-06  3217.550049  3246.840088  3214.639893  3246.280029  3246.280029
# 2020-01-07  3241.860107  3244.909912  3232.429932  3237.179932  3237.179932
# 2020-01-08  3238.590088  3267.070068  3236.669922  3253.050049  3253.050049
# ...                 ...          ...          ...          ...          ...
# 2020-12-24  3694.030029  3703.820068  3689.320068  3703.060059  3703.060059
# 2020-12-28  3723.030029  3740.510010  3723.030029  3735.360107  3735.360107
# 2020-12-29  3750.010010  3756.120117  3723.310059  3727.040039  3727.040039
# 2020-12-30  3736.189941  3744.629883  3730.209961  3732.040039  3732.040039
# ...

# %%
#Grafico de los precios de cierre
plt.figure(figsize=(10.8, 6.8))
plt.title("Tesla vs Mercado")
plt.xlabel("Fecha")
plt.ylabel("Precios de cierre")
plt.plot(df["Close"], color="red")
plt.plot(df2["Close"], color="blue")
plt.legend(["Tesla", "S&P500"], loc="lower right")
plt.show()

# %%
#Si deseamos comparar la inversion en cada activo, no podriamos ya que las magnitudes son distintas
#Escalar las series a un valor de 100$ (invertir 100$ y cuanto tendria en un tiempo determinado)
df["Close_100"] = (100/df["Close"][0])*df["Close"] #[0] para multiplicarlo con la primera entrada
df2["Close_100"] = (100/df2["Close"][0])*df2["Close"]
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02   28.299999   28.713333   28.114000   28.684000   28.684000
# 2020-01-03   29.366667   30.266666   29.128000   29.534000   29.534000
# 2020-01-06   29.364668   30.104000   29.333332   30.102667   30.102667
# 2020-01-07   30.760000   31.441999   30.224001   31.270666   31.270666
# 2020-01-08   31.580000   33.232666   31.215334   32.809334   32.809334
# ...                ...         ...         ...         ...         ...
# 2020-12-24  214.330002  222.029999  213.666672  220.589996  220.589996
# 2020-12-28  224.836670  227.133331  220.266663  221.229996  221.229996
# 2020-12-29  220.333328  223.300003  218.333328  221.996674  221.996674
# 2020-12-30  224.000000  232.199997  222.786667  231.593338  231.593338
# 2020-12-31  233.330002  239.573334  230.373337  235.223328  235.223328
#
#                Volume   Close_100
# Date
# 2020-01-02  142981500  100.000000
# ...

# %%
#Graficamos las series ajustadas a 100$
plt.figure(figsize=(10.8, 6.8))
plt.title("Tesla vs Mercado")
plt.xlabel("Fecha")
plt.ylabel("Precios de cierre escalados(2020-01-01=100)")
plt.plot(df["Close_100"], color="red")
plt.plot(df2["Close_100"], color="blue")
plt.legend(["Tesla", "S&P500"], loc="lower right")
plt.show()

# %%
from matplotlib import colors
#Diagrama de velas japonesas, incluimos libreria mplfinance y la importamos
mpf.plot(df[-42:], #para graficar los ultimos 2 meses
         hlines=dict(hlines=[175, 225], colors=["red", "green"], linestyle="-."),
         type="candle",
         volume=True,
         figratio=(10.8, 6.8),
         style= "yahoo",
         title="Velas japonesas Tesla"
)
