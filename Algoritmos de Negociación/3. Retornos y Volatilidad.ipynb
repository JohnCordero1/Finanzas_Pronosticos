# %%
#funciones numericas adicionales
import numpy as np

import pandas as pd
import yfinance as yfin
import matplotlib.pyplot as plt

# %%
df =yfin.download("AAPL", start="2019-01-01", end="2021-01-01")
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-01-02   38.722500   39.712502   38.557499   39.480000   38.047050
# 2019-01-03   35.994999   36.430000   35.500000   35.547501   34.257282
# 2019-01-04   36.132500   37.137501   35.950001   37.064999   35.719696
# 2019-01-07   37.174999   37.207500   36.474998   36.982498   35.640186
# 2019-01-08   37.389999   37.955002   37.130001   37.687500   36.319607
# ...                ...         ...         ...         ...         ...
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  130.205780
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  134.862656
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  133.067001
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  131.932373
# 2020-12-31  134.080002  134.740005  131.720001  132.690002  130.916107
#
#                Volume
# Date
# ...

# %%
#Retornos aritmeticos
df["Adj Close t-1"] = df["Adj Close"].shift(1) #shift desplaza filas
df["Retornos"] = (df["Adj Close"] - df["Adj Close t-1"])/df["Adj Close t-1"]
#Retornos logaritmicos
df["Log Returns"] = np.log(df["Adj Close"]) - np.log(df["Adj Close t-1"]) 
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2eb07e43dead> in <cell line: 2>()
#       1 #Retornos aritmeticos
# ----> 2 df["Close t-1"] = df["Close"].shift(1) #shift desplaza filas
#       3 df["Retornos"] = (df["Close"] - df["Close t-1"])/df["Close t-1"]
#       4 #Retornos logaritmicos
#       5 df["Log Returns"] = np.log(df["Close"]) - np.log(df["Close t-1"])
#
# NameError: name 'df' is not defined

# %%
#Graficar retornos
plt.figure(figsize=(10.8, 5.8))
plt.plot(df["Log Returns"], color = "red")
plt.title("Retornos logaritmicos")
plt.xlabel("Fecha")
plt.show()

# %%
#volatilidad diaria
vol_d = np.std(df["Log Returns"])

#Calculamos la volatilidad diaria anualizada (252 dias bursatiles)
vol_a = vol_d*np.sqrt(252)
vol_a
# Out:
# 0.3786473954387002

# %%
#Datos del S&P500
df2 =yfin.download("^GSPC", start="2015-01-01", end="2021-01-01")
df2
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2015-01-02  2058.899902  2072.360107  2046.040039  2058.199951  2058.199951
# 2015-01-05  2054.439941  2054.439941  2017.339966  2020.579956  2020.579956
# 2015-01-06  2022.150024  2030.250000  1992.439941  2002.609985  2002.609985
# 2015-01-07  2005.550049  2029.609985  2005.550049  2025.900024  2025.900024
# 2015-01-08  2030.609985  2064.080078  2030.609985  2062.139893  2062.139893
# ...                 ...          ...          ...          ...          ...
# 2020-12-24  3694.030029  3703.820068  3689.320068  3703.060059  3703.060059
# 2020-12-28  3723.030029  3740.510010  3723.030029  3735.360107  3735.360107
# 2020-12-29  3750.010010  3756.120117  3723.310059  3727.040039  3727.040039
# 2020-12-30  3736.189941  3744.629883  3730.209961  3732.040039  3732.040039
# ...

# %%
#Retornos aritmeticos
df2["Adj Close t-1"] = df2["Adj Close"].shift(1) #shift desplaza filas
df2["Retornos"] = (df2["Adj Close"] - df2["Adj Close t-1"])/df2["Adj Close t-1"]
#Retornos logaritmicos
df2["Log Returns"] = np.log(df2["Adj Close"]) - np.log(df2["Adj Close t-1"]) 
df2
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2015-01-02  2058.899902  2072.360107  2046.040039  2058.199951  2058.199951
# 2015-01-05  2054.439941  2054.439941  2017.339966  2020.579956  2020.579956
# 2015-01-06  2022.150024  2030.250000  1992.439941  2002.609985  2002.609985
# 2015-01-07  2005.550049  2029.609985  2005.550049  2025.900024  2025.900024
# 2015-01-08  2030.609985  2064.080078  2030.609985  2062.139893  2062.139893
# ...                 ...          ...          ...          ...          ...
# 2020-12-24  3694.030029  3703.820068  3689.320068  3703.060059  3703.060059
# 2020-12-28  3723.030029  3740.510010  3723.030029  3735.360107  3735.360107
# 2020-12-29  3750.010010  3756.120117  3723.310059  3727.040039  3727.040039
# 2020-12-30  3736.189941  3744.629883  3730.209961  3732.040039  3732.040039
# 2020-12-31  3733.270020  3760.199951  3726.879883  3756.070068  3756.070068
#
# ...

# %%
df2.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1511.000000  1511.000000  1511.000000  1511.000000  1511.000000
# mean   2580.552236  2593.403467  2566.244838  2580.769330  2580.769330
# std     452.726103   455.223784   450.255879   452.826691   452.826691
# min    1833.400024  1847.000000  1810.099976  1829.079956  1829.079956
# 25%    2123.404907  2130.660034  2115.059937  2125.030029  2125.030029
# 50%    2582.939941  2597.020020  2572.949951  2584.959961  2584.959961
# 75%    2892.529907  2902.844971  2877.790039  2888.460083  2888.460083
# max    3750.010010  3760.199951  3730.209961  3756.070068  3756.070068
#
#              Volume  Adj Close t-1     Retornos  Log Returns
# count  1.511000e+03    1510.000000  1510.000000  1510.000000
# mean   3.850408e+09    2579.990985     0.000468     0.000398
# std    9.564232e+08     451.964486     0.011758     0.011815
# min    1.296530e+09    1829.079956    -0.119841    -0.127652
# ...

# %%
#Retorno diario
ret_d = np.mean(df2["Log Returns"])
#Retorno anual de la forma ret_d*252
ret_a = ret_d*252
ret_a
# Out:
# 0.10038969485559751

# %%
#Retorno diario
ret_d2 = np.mean(df2["Retornos"])
#Retorno anual
ret_a2 = ret_d2*252
ret_a2
# Out:
# 0.11792710181217811

# %%
#volatilidad diaria S&P500
vol_dSPY = np.std(df2["Log Returns"])

#Calculamos la volatilidad diaria anualizada (252 dias bursatiles)
vol_aSPY = vol_dSPY*np.sqrt(252)
vol_aSPY
# Out:
# 0.1875009781369662

# %%
#volatilidad diaria S&P500
vol_dSPY2 = np.std(df2["Retornos"])

#Calculamos la volatilidad diaria anualizada (252 dias bursatiles)
vol_aSPY2 = vol_dSPY2*np.sqrt(252)
vol_aSPY2
# Out:
# 0.18658442679855516
